# %% [markdown]
# <a href="https://colab.research.google.com/github/jamunozlab/introductory_mechanics_fall_2023/blob/main/exercises/Phys_2320_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# ## Some relationships
#
# In mathematics, the additive inverse of a number $n$ is the number that when added to $n$, the result is zero:
#
# .
#
# $n\, +\, ? = 0$
#
# .
#
# That number is, of course, $-n$, the negative of $n$. The multiplicative inverse of a number $n$ is the number that when multiplied times $n$, the result is one:
#
# .
#
# $n\, \times\, ? = 1$
#
# .
#
# That number is, of course, $1/n$, the reciprocal of $n$. But there are more interesting relationships, for example, the *derivative* of the function $f(x) = x^n$ with respect to $x$ is:
#
# .
#
# $\frac{d}{dx}f(x) = nx^{n-1}$
#
# .
#
# Notice that rather than a single operation, taking the derivative of $x^n$ consists of *two* operations. It is a recipe, or an algorithm: multiply the variable $x$ times the exponent $n$, then subtract 1 from the exponent. Applying the inverse operations in the inverse direction yields the following: add 1 to the exponent, then divide by the variable $x$ by the exponent (which now is $n+1$). We call this the *integral* of $x^n$:
#
# .
#
# $\int f(x) dx = \int x^n dx = \frac{x^{n+1}}{n+1} + C$
#
# .
#
# The $C$ is just a constant which is needed because without limits of integration, an infinite of functions satisfy the equality above, but no need to worry about that now. Focus instead on the *relationships* between quantitites and on the *interpretation* of the derivative and the integral.
#
# .
#
# <u>Of particular importance</u>, if the derivative is approximately the slope of a function, rise $\div$ run, and the integral is the algorithmic inverse, then the integral must be approximately rise $\times$ run... <u>the area under the curve!<u>

# %% [markdown]
# ## On integrals and computers (or why you are doing this)
#
# When Isaac Newton first envisioned the rules of motion that describe the mechanical universe, the mathematics to describe them did not exist, so he invented them. While addition and multiplication can take us a long way, calculus is the actual language that the Universe speaks. At least the mechanical universe.
#
# Calculus is based on infinitively small changes, but computers can only compute operations with finite numbers. Nevertheless, you can make those finite numbers as small as you want, and tell the computer to go through all of them. So while a computer cannot give you an analytical solution (a formula), it can certainly give you a numerical solution (as many numbers as you want).
#
# Here we will use computers to understant the relationships between acceleration, velocity, and position.

# %% [markdown]
# # Instructions
#
# 1. Evaluate the cells below, in some cases you might need to complete the code.
#
# 2. Complete the exercises.
#
# 3. Answer the questions in the space provided.
#
# NOTE: You do not need to know anything about pandas or lambda functions or even while loops right now. Your teaching assistant will demonstrate on the whiteboard what the code below is doing.

# %%
import pandas as pd

# %%
# These variables are used to define a quadratic function of the form At^2 + Bt + C
A = 4  #m/s^4
B = -5 #m/s^3
C = 3  #m/s^2

# %%
# This loop will evaluate the quadratic function with A, B, C as above
# It will save the result for each instant t so that you can plot it

time = 0
resolution = 0.01 # Δt, you can make it big or small
time_list = []    #Declare empty array  "time_list"
acceleration_list = [] # Declare empty array variable "acceleration list"
while time < 2.0: # WHILE LOOP, if "time" is LESS THAN 2, do this:
  time_list.append(time) # APPENED TIME LIST
  acceleration_list.append((lambda t: A*t**2 + B*t + C)(time)) # APPEND "acceleration_list" with the solution to the function "f(t) = 4t^2 + (-5)t+(3)""
  time = time + resolution # INCREMENT TIME BY RESOLUTION

acceleration_vs_time = pd.Series(acceleration_list, index=time_list) # DEFINE A TWO COLUMN ARRAY VARIABLE CONSISTING OF ACCEL/TIME
print(acceleration_vs_time) # This two column arrray variable will allow  us to store and graph our data later using "pandas"

#// This "while loop" first computes the acceleration at time(t = 0) using the "lamba" function defined initially as: f(t)= 4(0)^2 + (-5)(0)+(3) => 3.
# Once that acceleration has been computed, that value is then appended to the array variable "acceleration_list",
# Finally the "time" variable is incremented by the resolution "0.1", just before the loop interates itselt again.

# This "while loop" iterates a total of 200 times from t=0 to t=1.99 until the LOOP EXIT CONDITION (while time < 2.0) is met. //
# Out:
# 0.00    3.0000
# 0.01    2.9504
# 0.02    2.9016
# 0.03    2.8536
# 0.04    2.8064
#          ...
# 1.95    8.4600
# 1.96    8.5664
# 1.97    8.6736
# 1.98    8.7816
# 1.99    8.8904
# Length: 200, dtype: float64

# %%
acceleration_vs_time.plot(xlabel = "Time (s)", ylabel = "acceleration (m/s)", xlim=(0, 2), ylim=(0, acceleration_vs_time.max() + 1))

#// in this code cell we use pandas ".plot" function to display our generated data. //
# Out:
# <Axes: xlabel='Time (s)', ylabel='acceleration (m/s)'>

# %%
# Now we will use this data to estimate "The area under the curve" (velocity) of this acceleration/time function.

# %%
# This loop computes the integral of the quadratic function with A, B, C as above
# It does so by computing the area of every narrow (width=0.01 seconds) but tall (height=acceleration in m/s^2) rectangle
# and adding all the areas together

initial_velocity = 0
final_velocity = initial_velocity
final_velocity_list = [] # final_velocity, and initial_velocity set to "0"
for i in range(len(acceleration_vs_time)): #This line defines a "for loop" that will dynamically iterate for every element in our array variable; exactly 200 times in our case here.
  area_of_rectangle = acceleration_vs_time.iloc[i] * resolution # Area of rectangle is modeled by the equation : Length*Width or L*W
  final_velocity = final_velocity + area_of_rectangle #ADD "area_of_rectangle" to the value of "final_velocity"
  final_velocity_list.append(final_velocity) # APPEND new computed velocity value to our array variable "final_velocity_list"
  print("This iteration computes the area of the ", i, "th rectangle")
  print("The area under the curve is the change in velocity (meters per second):", area_of_rectangle) # DISPLAY the area of each rectangle as a concurrent list of the "change in velocities" that occur in our function
  print("The cummulative area under the curve is the overall change in velocity until this point (meters per second):", final_velocity) # finally, this command displays the sum of all of our changes in "velocity", giving us a "final_velocity"\
  print("")
# Out:
# This iteration computes the area of the  0 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.03
#
# This iteration computes the area of the  1 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.029504000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.059504
#
# This iteration computes the area of the  2 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.029016000000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.08852
#
# This iteration computes the area of the  3 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.028536000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.11705600000000001
#
# This iteration computes the area of the  4 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.028064000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.14512
#
# This iteration computes the area of the  5 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.0276
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.17271999999999998
#
# This iteration computes the area of the  6 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.027144
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.19986399999999999
#
# This iteration computes the area of the  7 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.026696
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.22655999999999998
#
# This iteration computes the area of the  8 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.026256
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.252816
#
# This iteration computes the area of the  9 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.025824
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.27864
#
# This iteration computes the area of the  10 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.025400000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.30404
#
# This iteration computes the area of the  11 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.024984000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.329024
#
# This iteration computes the area of the  12 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.024576000000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.35359999999999997
#
# This iteration computes the area of the  13 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.024176000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.377776
#
# This iteration computes the area of the  14 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.023784
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.40156000000000003
#
# This iteration computes the area of the  15 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.0234
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.42496
#
# This iteration computes the area of the  16 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.023024
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.447984
#
# This iteration computes the area of the  17 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.022656000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.47064
#
# This iteration computes the area of the  18 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.022296
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.492936
#
# This iteration computes the area of the  19 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.021943999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.51488
#
# This iteration computes the area of the  20 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.021599999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.53648
#
# This iteration computes the area of the  21 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.021263999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.5577439999999999
#
# This iteration computes the area of the  22 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.020936
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.5786799999999999
#
# This iteration computes the area of the  23 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.020616
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.5992959999999998
#
# This iteration computes the area of the  24 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.020304
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.6195999999999998
#
# This iteration computes the area of the  25 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.6395999999999998
#
# This iteration computes the area of the  26 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.019704
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.6593039999999999
#
# This iteration computes the area of the  27 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.019416
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.6787199999999999
#
# This iteration computes the area of the  28 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.019135999999999997
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.6978559999999999
#
# This iteration computes the area of the  29 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.018864
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.7167199999999999
#
# This iteration computes the area of the  30 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.0186
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.7353199999999999
#
# This iteration computes the area of the  31 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.018344
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.7536639999999999
#
# This iteration computes the area of the  32 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.018095999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.7717599999999999
#
# This iteration computes the area of the  33 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.017855999999999997
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.7896159999999999
#
# This iteration computes the area of the  34 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.017623999999999997
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.8072399999999998
#
# This iteration computes the area of the  35 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.0174
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.8246399999999998
#
# This iteration computes the area of the  36 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.017183999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.8418239999999998
#
# This iteration computes the area of the  37 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016975999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.8587999999999998
#
# This iteration computes the area of the  38 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016776
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.8755759999999998
#
# This iteration computes the area of the  39 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016583999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.8921599999999998
#
# This iteration computes the area of the  40 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016399999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.9085599999999998
#
# This iteration computes the area of the  41 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016223999999999995
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.9247839999999998
#
# This iteration computes the area of the  42 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016055999999999997
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.9408399999999998
#
# This iteration computes the area of the  43 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015895999999999993
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.9567359999999998
#
# This iteration computes the area of the  44 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015743999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.9724799999999998
#
# This iteration computes the area of the  45 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015599999999999996
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 0.9880799999999997
#
# This iteration computes the area of the  46 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015463999999999999
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0035439999999998
#
# This iteration computes the area of the  47 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015335999999999994
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0188799999999998
#
# This iteration computes the area of the  48 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015215999999999999
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0340959999999997
#
# This iteration computes the area of the  49 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015103999999999996
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0491999999999997
#
# This iteration computes the area of the  50 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0641999999999996
#
# This iteration computes the area of the  51 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014903999999999997
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0791039999999996
#
# This iteration computes the area of the  52 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014815999999999996
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.0939199999999996
#
# This iteration computes the area of the  53 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014735999999999999
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1086559999999996
#
# This iteration computes the area of the  54 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014664000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1233199999999997
#
# This iteration computes the area of the  55 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014599999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1379199999999996
#
# This iteration computes the area of the  56 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014543999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1524639999999995
#
# This iteration computes the area of the  57 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014495999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1669599999999996
#
# This iteration computes the area of the  58 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014456000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1814159999999996
#
# This iteration computes the area of the  59 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014424
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.1958399999999996
#
# This iteration computes the area of the  60 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014399999999999998
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2102399999999995
#
# This iteration computes the area of the  61 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014384
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2246239999999995
#
# This iteration computes the area of the  62 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014376000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2389999999999994
#
# This iteration computes the area of the  63 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014376
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2533759999999994
#
# This iteration computes the area of the  64 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014384
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2677599999999993
#
# This iteration computes the area of the  65 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014400000000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2821599999999993
#
# This iteration computes the area of the  66 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014424000000000005
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.2965839999999993
#
# This iteration computes the area of the  67 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014456000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3110399999999993
#
# This iteration computes the area of the  68 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014496
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3255359999999994
#
# This iteration computes the area of the  69 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014544000000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3400799999999995
#
# This iteration computes the area of the  70 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014600000000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3546799999999994
#
# This iteration computes the area of the  71 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014664000000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3693439999999995
#
# This iteration computes the area of the  72 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014736000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3840799999999995
#
# This iteration computes the area of the  73 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014816000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.3988959999999995
#
# This iteration computes the area of the  74 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.014904000000000006
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.4137999999999995
#
# This iteration computes the area of the  75 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015000000000000005
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.4287999999999994
#
# This iteration computes the area of the  76 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015104000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.4439039999999994
#
# This iteration computes the area of the  77 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015216000000000007
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.4591199999999995
#
# This iteration computes the area of the  78 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015336000000000008
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.4744559999999995
#
# This iteration computes the area of the  79 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015464000000000007
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.4899199999999995
#
# This iteration computes the area of the  80 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015600000000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.5055199999999995
#
# This iteration computes the area of the  81 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015744000000000008
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.5212639999999995
#
# This iteration computes the area of the  82 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.015896000000000007
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.5371599999999994
#
# This iteration computes the area of the  83 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01605600000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.5532159999999995
#
# This iteration computes the area of the  84 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01622400000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.5694399999999995
#
# This iteration computes the area of the  85 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016400000000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.5858399999999995
#
# This iteration computes the area of the  86 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016584000000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.6024239999999994
#
# This iteration computes the area of the  87 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.016776000000000006
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.6191999999999993
#
# This iteration computes the area of the  88 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01697600000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.6361759999999994
#
# This iteration computes the area of the  89 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.017184000000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.6533599999999995
#
# This iteration computes the area of the  90 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.017400000000000016
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.6707599999999996
#
# This iteration computes the area of the  91 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.017624000000000018
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.6883839999999997
#
# This iteration computes the area of the  92 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01785600000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.7062399999999998
#
# This iteration computes the area of the  93 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.018096000000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.7243359999999999
#
# This iteration computes the area of the  94 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01834400000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.7426799999999998
#
# This iteration computes the area of the  95 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.018600000000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.7612799999999997
#
# This iteration computes the area of the  96 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.018864000000000016
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.7801439999999997
#
# This iteration computes the area of the  97 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01913600000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.7992799999999998
#
# This iteration computes the area of the  98 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.01941600000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.8186959999999999
#
# This iteration computes the area of the  99 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.019704000000000024
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.8383999999999998
#
# This iteration computes the area of the  100 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.020000000000000018
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.8583999999999998
#
# This iteration computes the area of the  101 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02030400000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.878704
#
# This iteration computes the area of the  102 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02061600000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.89932
#
# This iteration computes the area of the  103 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02093600000000002
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.920256
#
# This iteration computes the area of the  104 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.021264000000000022
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.94152
#
# This iteration computes the area of the  105 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02160000000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.96312
#
# This iteration computes the area of the  106 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.021944000000000026
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 1.985064
#
# This iteration computes the area of the  107 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02229600000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.00736
#
# This iteration computes the area of the  108 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.022656000000000027
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.030016
#
# This iteration computes the area of the  109 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02302400000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.0530399999999998
#
# This iteration computes the area of the  110 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.023400000000000035
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.07644
#
# This iteration computes the area of the  111 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.023784000000000027
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.100224
#
# This iteration computes the area of the  112 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02417600000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.1244
#
# This iteration computes the area of the  113 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02457600000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.148976
#
# This iteration computes the area of the  114 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.024984000000000037
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.17396
#
# This iteration computes the area of the  115 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.025400000000000037
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.19936
#
# This iteration computes the area of the  116 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.025824000000000034
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.225184
#
# This iteration computes the area of the  117 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02625600000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.25144
#
# This iteration computes the area of the  118 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.026696000000000036
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.278136
#
# This iteration computes the area of the  119 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.02714400000000003
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.3052799999999998
#
# This iteration computes the area of the  120 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.027600000000000034
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.33288
#
# This iteration computes the area of the  121 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.028064000000000037
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.360944
#
# This iteration computes the area of the  122 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.028536000000000047
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.38948
#
# This iteration computes the area of the  123 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.029016000000000045
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.4184959999999998
#
# This iteration computes the area of the  124 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.029504000000000037
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.448
#
# This iteration computes the area of the  125 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.030000000000000044
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.478
#
# This iteration computes the area of the  126 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.030504000000000052
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.5085040000000003
#
# This iteration computes the area of the  127 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03101600000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.5395200000000004
#
# This iteration computes the area of the  128 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03153600000000004
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.5710560000000005
#
# This iteration computes the area of the  129 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03206400000000005
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.6031200000000005
#
# This iteration computes the area of the  130 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03260000000000005
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.6357200000000005
#
# This iteration computes the area of the  131 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.033144000000000055
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.6688640000000006
#
# This iteration computes the area of the  132 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03369600000000005
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.7025600000000005
#
# This iteration computes the area of the  133 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03425600000000006
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.7368160000000006
#
# This iteration computes the area of the  134 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.034824000000000056
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.7716400000000005
#
# This iteration computes the area of the  135 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.035400000000000056
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.8070400000000006
#
# This iteration computes the area of the  136 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03598400000000005
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.8430240000000007
#
# This iteration computes the area of the  137 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03657600000000006
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.879600000000001
#
# This iteration computes the area of the  138 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03717600000000006
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.916776000000001
#
# This iteration computes the area of the  139 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03778400000000007
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.954560000000001
#
# This iteration computes the area of the  140 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03840000000000006
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 2.9929600000000014
#
# This iteration computes the area of the  141 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.039024000000000066
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.0319840000000013
#
# This iteration computes the area of the  142 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.03965600000000007
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.0716400000000013
#
# This iteration computes the area of the  143 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.040296000000000054
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.1119360000000014
#
# This iteration computes the area of the  144 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.040944000000000064
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.1528800000000015
#
# This iteration computes the area of the  145 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.041600000000000074
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.1944800000000013
#
# This iteration computes the area of the  146 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04226400000000008
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.2367440000000016
#
# This iteration computes the area of the  147 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.042936000000000085
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.2796800000000017
#
# This iteration computes the area of the  148 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.043616000000000085
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.323296000000002
#
# This iteration computes the area of the  149 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.044304000000000066
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.3676000000000017
#
# This iteration computes the area of the  150 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04500000000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.4126000000000016
#
# This iteration computes the area of the  151 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.045704000000000085
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.458304000000002
#
# This iteration computes the area of the  152 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04641600000000008
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.504720000000002
#
# This iteration computes the area of the  153 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04713600000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.551856000000002
#
# This iteration computes the area of the  154 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04786400000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.5997200000000023
#
# This iteration computes the area of the  155 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04860000000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.6483200000000022
#
# This iteration computes the area of the  156 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.04934400000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.6976640000000023
#
# This iteration computes the area of the  157 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.050096000000000085
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.747760000000002
#
# This iteration computes the area of the  158 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.0508560000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.798616000000002
#
# This iteration computes the area of the  159 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.051624000000000086
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.850240000000002
#
# This iteration computes the area of the  160 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.05240000000000011
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.902640000000002
#
# This iteration computes the area of the  161 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.05318400000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 3.955824000000002
#
# This iteration computes the area of the  162 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.05397600000000009
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.009800000000002
#
# This iteration computes the area of the  163 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.054776000000000095
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.064576000000002
#
# This iteration computes the area of the  164 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.0555840000000001
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.120160000000003
#
# This iteration computes the area of the  165 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.056400000000000096
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.176560000000003
#
# This iteration computes the area of the  166 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.05722400000000011
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.233784000000003
#
# This iteration computes the area of the  167 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.05805600000000011
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.291840000000002
#
# This iteration computes the area of the  168 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.05889600000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.350736000000002
#
# This iteration computes the area of the  169 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.059744000000000116
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.410480000000002
#
# This iteration computes the area of the  170 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06060000000000011
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.471080000000002
#
# This iteration computes the area of the  171 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06146400000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.532544000000002
#
# This iteration computes the area of the  172 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06233600000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.5948800000000025
#
# This iteration computes the area of the  173 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06321600000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.658096000000002
#
# This iteration computes the area of the  174 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06410400000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.722200000000003
#
# This iteration computes the area of the  175 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06500000000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.787200000000003
#
# This iteration computes the area of the  176 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06590400000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.853104000000003
#
# This iteration computes the area of the  177 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06681600000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.919920000000003
#
# This iteration computes the area of the  178 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06773600000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 4.987656000000003
#
# This iteration computes the area of the  179 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06866400000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.056320000000003
#
# This iteration computes the area of the  180 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.06960000000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.125920000000003
#
# This iteration computes the area of the  181 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07054400000000012
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.196464000000003
#
# This iteration computes the area of the  182 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07149600000000014
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.267960000000003
#
# This iteration computes the area of the  183 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07245600000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.340416000000003
#
# This iteration computes the area of the  184 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07342400000000014
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.413840000000003
#
# This iteration computes the area of the  185 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07440000000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.488240000000003
#
# This iteration computes the area of the  186 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07538400000000013
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.5636240000000035
#
# This iteration computes the area of the  187 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07637600000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.640000000000003
#
# This iteration computes the area of the  188 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07737600000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.717376000000003
#
# This iteration computes the area of the  189 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07838400000000016
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.795760000000003
#
# This iteration computes the area of the  190 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.07940000000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.875160000000004
#
# This iteration computes the area of the  191 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08042400000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 5.9555840000000035
#
# This iteration computes the area of the  192 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08145600000000017
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.037040000000004
#
# This iteration computes the area of the  193 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08249600000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.119536000000004
#
# This iteration computes the area of the  194 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08354400000000015
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.2030800000000035
#
# This iteration computes the area of the  195 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08460000000000018
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.2876800000000035
#
# This iteration computes the area of the  196 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08566400000000016
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.373344000000004
#
# This iteration computes the area of the  197 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08673600000000016
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.460080000000004
#
# This iteration computes the area of the  198 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08781600000000017
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.547896000000004
#
# This iteration computes the area of the  199 th rectangle
# The area under the curve is the change in velocity (meters per second): 0.08890400000000016
# The cummulative area under the curve is the overall change in velocity until this point (meters per second): 6.6368000000000045

# %%
# This cell allows us to plot the velocity as a function of time

velocity_vs_time = pd.Series(final_velocity_list, index=time_list) #Define a two(2) column array variable consisting of the variables "final_velocity_list" and "time"
velocity_vs_time.plot(xlabel = "Time (s)", ylabel = "velocity (m/s)", xlim=(0, 2), ylim=(0, velocity_vs_time.max() + 1), colormap='RdBu')
# Out:
# <Axes: xlabel='Time (s)', ylabel='velocity (m/s)'>

# %%
# If you believe calculus, the area under the curve of the velocity vs time graph
# gives you the position

# %%
initial_position = 0
final_position = initial_position
final_position_list = []
for i in range(len(velocity_vs_time)): #same size as Velocityvstime array
  area_of_rectangle = velocity_vs_time.iloc[i] * resolution # ΔPOSITION = VELOCITY*RESOLUTION | Areaofrectangle = L*W
  final_position = final_position + area_of_rectangle
  final_position_list.append(final_position)
#  print(area_of_rectangle, "meters")

  print("This iteration computes the area of the ", i, "th rectangle")
  print("The area under the curve is the change in position (meters):", area_of_rectangle)
  print("The cummulative area under the curve is the overall change in position until this point (meters):", final_position)
  print("")
# Out:
# This iteration computes the area of the  0 th rectangle
# The area under the curve is the change in position (meters): 0.0003
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0003
#
# This iteration computes the area of the  1 th rectangle
# The area under the curve is the change in position (meters): 0.00059504
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0008950399999999999
#
# This iteration computes the area of the  2 th rectangle
# The area under the curve is the change in position (meters): 0.0008852
# The cummulative area under the curve is the overall change in position until this point (meters): 0.00178024
#
# This iteration computes the area of the  3 th rectangle
# The area under the curve is the change in position (meters): 0.0011705600000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0029508
#
# This iteration computes the area of the  4 th rectangle
# The area under the curve is the change in position (meters): 0.0014512
# The cummulative area under the curve is the overall change in position until this point (meters): 0.004402
#
# This iteration computes the area of the  5 th rectangle
# The area under the curve is the change in position (meters): 0.0017272
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0061292
#
# This iteration computes the area of the  6 th rectangle
# The area under the curve is the change in position (meters): 0.00199864
# The cummulative area under the curve is the overall change in position until this point (meters): 0.008127839999999999
#
# This iteration computes the area of the  7 th rectangle
# The area under the curve is the change in position (meters): 0.0022656
# The cummulative area under the curve is the overall change in position until this point (meters): 0.010393439999999999
#
# This iteration computes the area of the  8 th rectangle
# The area under the curve is the change in position (meters): 0.0025281599999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.012921599999999998
#
# This iteration computes the area of the  9 th rectangle
# The area under the curve is the change in position (meters): 0.0027864
# The cummulative area under the curve is the overall change in position until this point (meters): 0.015708
#
# This iteration computes the area of the  10 th rectangle
# The area under the curve is the change in position (meters): 0.0030404
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0187484
#
# This iteration computes the area of the  11 th rectangle
# The area under the curve is the change in position (meters): 0.00329024
# The cummulative area under the curve is the overall change in position until this point (meters): 0.022038639999999998
#
# This iteration computes the area of the  12 th rectangle
# The area under the curve is the change in position (meters): 0.0035359999999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.02557464
#
# This iteration computes the area of the  13 th rectangle
# The area under the curve is the change in position (meters): 0.0037777600000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0293524
#
# This iteration computes the area of the  14 th rectangle
# The area under the curve is the change in position (meters): 0.0040156
# The cummulative area under the curve is the overall change in position until this point (meters): 0.033368
#
# This iteration computes the area of the  15 th rectangle
# The area under the curve is the change in position (meters): 0.0042496
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0376176
#
# This iteration computes the area of the  16 th rectangle
# The area under the curve is the change in position (meters): 0.00447984
# The cummulative area under the curve is the overall change in position until this point (meters): 0.04209744
#
# This iteration computes the area of the  17 th rectangle
# The area under the curve is the change in position (meters): 0.0047064
# The cummulative area under the curve is the overall change in position until this point (meters): 0.04680384
#
# This iteration computes the area of the  18 th rectangle
# The area under the curve is the change in position (meters): 0.00492936
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0517332
#
# This iteration computes the area of the  19 th rectangle
# The area under the curve is the change in position (meters): 0.0051488
# The cummulative area under the curve is the overall change in position until this point (meters): 0.056882
#
# This iteration computes the area of the  20 th rectangle
# The area under the curve is the change in position (meters): 0.005364799999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.062246800000000005
#
# This iteration computes the area of the  21 th rectangle
# The area under the curve is the change in position (meters): 0.0055774399999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.06782424000000001
#
# This iteration computes the area of the  22 th rectangle
# The area under the curve is the change in position (meters): 0.005786799999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.07361104
#
# This iteration computes the area of the  23 th rectangle
# The area under the curve is the change in position (meters): 0.0059929599999999986
# The cummulative area under the curve is the overall change in position until this point (meters): 0.07960400000000001
#
# This iteration computes the area of the  24 th rectangle
# The area under the curve is the change in position (meters): 0.006195999999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.0858
#
# This iteration computes the area of the  25 th rectangle
# The area under the curve is the change in position (meters): 0.006395999999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.092196
#
# This iteration computes the area of the  26 th rectangle
# The area under the curve is the change in position (meters): 0.006593039999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.09878904
#
# This iteration computes the area of the  27 th rectangle
# The area under the curve is the change in position (meters): 0.006787199999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.10557623999999999
#
# This iteration computes the area of the  28 th rectangle
# The area under the curve is the change in position (meters): 0.006978559999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.11255479999999998
#
# This iteration computes the area of the  29 th rectangle
# The area under the curve is the change in position (meters): 0.0071671999999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.11972199999999998
#
# This iteration computes the area of the  30 th rectangle
# The area under the curve is the change in position (meters): 0.007353199999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.12707519999999997
#
# This iteration computes the area of the  31 th rectangle
# The area under the curve is the change in position (meters): 0.007536639999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.13461183999999998
#
# This iteration computes the area of the  32 th rectangle
# The area under the curve is the change in position (meters): 0.007717599999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.14232943999999997
#
# This iteration computes the area of the  33 th rectangle
# The area under the curve is the change in position (meters): 0.00789616
# The cummulative area under the curve is the overall change in position until this point (meters): 0.15022559999999996
#
# This iteration computes the area of the  34 th rectangle
# The area under the curve is the change in position (meters): 0.008072399999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.15829799999999997
#
# This iteration computes the area of the  35 th rectangle
# The area under the curve is the change in position (meters): 0.008246399999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.16654439999999995
#
# This iteration computes the area of the  36 th rectangle
# The area under the curve is the change in position (meters): 0.008418239999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.17496263999999995
#
# This iteration computes the area of the  37 th rectangle
# The area under the curve is the change in position (meters): 0.008587999999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.18355063999999993
#
# This iteration computes the area of the  38 th rectangle
# The area under the curve is the change in position (meters): 0.008755759999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.19230639999999993
#
# This iteration computes the area of the  39 th rectangle
# The area under the curve is the change in position (meters): 0.008921599999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.20122799999999993
#
# This iteration computes the area of the  40 th rectangle
# The area under the curve is the change in position (meters): 0.009085599999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.21031359999999993
#
# This iteration computes the area of the  41 th rectangle
# The area under the curve is the change in position (meters): 0.009247839999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.21956143999999994
#
# This iteration computes the area of the  42 th rectangle
# The area under the curve is the change in position (meters): 0.009408399999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.22896983999999992
#
# This iteration computes the area of the  43 th rectangle
# The area under the curve is the change in position (meters): 0.009567359999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.23853719999999992
#
# This iteration computes the area of the  44 th rectangle
# The area under the curve is the change in position (meters): 0.009724799999999999
# The cummulative area under the curve is the overall change in position until this point (meters): 0.24826199999999993
#
# This iteration computes the area of the  45 th rectangle
# The area under the curve is the change in position (meters): 0.009880799999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.25814279999999995
#
# This iteration computes the area of the  46 th rectangle
# The area under the curve is the change in position (meters): 0.010035439999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.26817823999999996
#
# This iteration computes the area of the  47 th rectangle
# The area under the curve is the change in position (meters): 0.010188799999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.27836703999999995
#
# This iteration computes the area of the  48 th rectangle
# The area under the curve is the change in position (meters): 0.010340959999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.28870799999999996
#
# This iteration computes the area of the  49 th rectangle
# The area under the curve is the change in position (meters): 0.010491999999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.29919999999999997
#
# This iteration computes the area of the  50 th rectangle
# The area under the curve is the change in position (meters): 0.010641999999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.30984199999999995
#
# This iteration computes the area of the  51 th rectangle
# The area under the curve is the change in position (meters): 0.010791039999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.3206330399999999
#
# This iteration computes the area of the  52 th rectangle
# The area under the curve is the change in position (meters): 0.010939199999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.3315722399999999
#
# This iteration computes the area of the  53 th rectangle
# The area under the curve is the change in position (meters): 0.011086559999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.34265879999999993
#
# This iteration computes the area of the  54 th rectangle
# The area under the curve is the change in position (meters): 0.011233199999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.35389199999999993
#
# This iteration computes the area of the  55 th rectangle
# The area under the curve is the change in position (meters): 0.011379199999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.3652711999999999
#
# This iteration computes the area of the  56 th rectangle
# The area under the curve is the change in position (meters): 0.011524639999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.3767958399999999
#
# This iteration computes the area of the  57 th rectangle
# The area under the curve is the change in position (meters): 0.011669599999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.3884654399999999
#
# This iteration computes the area of the  58 th rectangle
# The area under the curve is the change in position (meters): 0.011814159999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.4002795999999999
#
# This iteration computes the area of the  59 th rectangle
# The area under the curve is the change in position (meters): 0.011958399999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.4122379999999999
#
# This iteration computes the area of the  60 th rectangle
# The area under the curve is the change in position (meters): 0.012102399999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.4243403999999999
#
# This iteration computes the area of the  61 th rectangle
# The area under the curve is the change in position (meters): 0.012246239999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.4365866399999999
#
# This iteration computes the area of the  62 th rectangle
# The area under the curve is the change in position (meters): 0.012389999999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.4489766399999999
#
# This iteration computes the area of the  63 th rectangle
# The area under the curve is the change in position (meters): 0.012533759999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.46151039999999993
#
# This iteration computes the area of the  64 th rectangle
# The area under the curve is the change in position (meters): 0.012677599999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.47418799999999994
#
# This iteration computes the area of the  65 th rectangle
# The area under the curve is the change in position (meters): 0.012821599999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.48700959999999993
#
# This iteration computes the area of the  66 th rectangle
# The area under the curve is the change in position (meters): 0.012965839999999992
# The cummulative area under the curve is the overall change in position until this point (meters): 0.49997543999999994
#
# This iteration computes the area of the  67 th rectangle
# The area under the curve is the change in position (meters): 0.013110399999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5130858399999999
#
# This iteration computes the area of the  68 th rectangle
# The area under the curve is the change in position (meters): 0.013255359999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5263411999999998
#
# This iteration computes the area of the  69 th rectangle
# The area under the curve is the change in position (meters): 0.013400799999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5397419999999998
#
# This iteration computes the area of the  70 th rectangle
# The area under the curve is the change in position (meters): 0.013546799999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5532887999999998
#
# This iteration computes the area of the  71 th rectangle
# The area under the curve is the change in position (meters): 0.013693439999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5669822399999997
#
# This iteration computes the area of the  72 th rectangle
# The area under the curve is the change in position (meters): 0.013840799999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5808230399999997
#
# This iteration computes the area of the  73 th rectangle
# The area under the curve is the change in position (meters): 0.013988959999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.5948119999999997
#
# This iteration computes the area of the  74 th rectangle
# The area under the curve is the change in position (meters): 0.014137999999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6089499999999997
#
# This iteration computes the area of the  75 th rectangle
# The area under the curve is the change in position (meters): 0.014287999999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6232379999999996
#
# This iteration computes the area of the  76 th rectangle
# The area under the curve is the change in position (meters): 0.014439039999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6376770399999996
#
# This iteration computes the area of the  77 th rectangle
# The area under the curve is the change in position (meters): 0.014591199999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6522682399999996
#
# This iteration computes the area of the  78 th rectangle
# The area under the curve is the change in position (meters): 0.014744559999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6670127999999996
#
# This iteration computes the area of the  79 th rectangle
# The area under the curve is the change in position (meters): 0.014899199999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6819119999999996
#
# This iteration computes the area of the  80 th rectangle
# The area under the curve is the change in position (meters): 0.015055199999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.6969671999999997
#
# This iteration computes the area of the  81 th rectangle
# The area under the curve is the change in position (meters): 0.015212639999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.7121798399999997
#
# This iteration computes the area of the  82 th rectangle
# The area under the curve is the change in position (meters): 0.015371599999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.7275514399999997
#
# This iteration computes the area of the  83 th rectangle
# The area under the curve is the change in position (meters): 0.015532159999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.7430835999999997
#
# This iteration computes the area of the  84 th rectangle
# The area under the curve is the change in position (meters): 0.015694399999999994
# The cummulative area under the curve is the overall change in position until this point (meters): 0.7587779999999997
#
# This iteration computes the area of the  85 th rectangle
# The area under the curve is the change in position (meters): 0.015858399999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.7746363999999997
#
# This iteration computes the area of the  86 th rectangle
# The area under the curve is the change in position (meters): 0.016024239999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.7906606399999997
#
# This iteration computes the area of the  87 th rectangle
# The area under the curve is the change in position (meters): 0.016191999999999995
# The cummulative area under the curve is the overall change in position until this point (meters): 0.8068526399999997
#
# This iteration computes the area of the  88 th rectangle
# The area under the curve is the change in position (meters): 0.016361759999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.8232143999999997
#
# This iteration computes the area of the  89 th rectangle
# The area under the curve is the change in position (meters): 0.016533599999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.8397479999999997
#
# This iteration computes the area of the  90 th rectangle
# The area under the curve is the change in position (meters): 0.016707599999999996
# The cummulative area under the curve is the overall change in position until this point (meters): 0.8564555999999998
#
# This iteration computes the area of the  91 th rectangle
# The area under the curve is the change in position (meters): 0.016883839999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 0.8733394399999997
#
# This iteration computes the area of the  92 th rectangle
# The area under the curve is the change in position (meters): 0.0170624
# The cummulative area under the curve is the overall change in position until this point (meters): 0.8904018399999998
#
# This iteration computes the area of the  93 th rectangle
# The area under the curve is the change in position (meters): 0.01724336
# The cummulative area under the curve is the overall change in position until this point (meters): 0.9076451999999998
#
# This iteration computes the area of the  94 th rectangle
# The area under the curve is the change in position (meters): 0.0174268
# The cummulative area under the curve is the overall change in position until this point (meters): 0.9250719999999998
#
# This iteration computes the area of the  95 th rectangle
# The area under the curve is the change in position (meters): 0.017612799999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.9426847999999998
#
# This iteration computes the area of the  96 th rectangle
# The area under the curve is the change in position (meters): 0.017801439999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 0.9604862399999997
#
# This iteration computes the area of the  97 th rectangle
# The area under the curve is the change in position (meters): 0.0179928
# The cummulative area under the curve is the overall change in position until this point (meters): 0.9784790399999997
#
# This iteration computes the area of the  98 th rectangle
# The area under the curve is the change in position (meters): 0.01818696
# The cummulative area under the curve is the overall change in position until this point (meters): 0.9966659999999997
#
# This iteration computes the area of the  99 th rectangle
# The area under the curve is the change in position (meters): 0.018383999999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 1.0150499999999998
#
# This iteration computes the area of the  100 th rectangle
# The area under the curve is the change in position (meters): 0.018584
# The cummulative area under the curve is the overall change in position until this point (meters): 1.0336339999999997
#
# This iteration computes the area of the  101 th rectangle
# The area under the curve is the change in position (meters): 0.01878704
# The cummulative area under the curve is the overall change in position until this point (meters): 1.0524210399999998
#
# This iteration computes the area of the  102 th rectangle
# The area under the curve is the change in position (meters): 0.0189932
# The cummulative area under the curve is the overall change in position until this point (meters): 1.0714142399999997
#
# This iteration computes the area of the  103 th rectangle
# The area under the curve is the change in position (meters): 0.01920256
# The cummulative area under the curve is the overall change in position until this point (meters): 1.0906167999999998
#
# This iteration computes the area of the  104 th rectangle
# The area under the curve is the change in position (meters): 0.0194152
# The cummulative area under the curve is the overall change in position until this point (meters): 1.110032
#
# This iteration computes the area of the  105 th rectangle
# The area under the curve is the change in position (meters): 0.0196312
# The cummulative area under the curve is the overall change in position until this point (meters): 1.1296632
#
# This iteration computes the area of the  106 th rectangle
# The area under the curve is the change in position (meters): 0.01985064
# The cummulative area under the curve is the overall change in position until this point (meters): 1.14951384
#
# This iteration computes the area of the  107 th rectangle
# The area under the curve is the change in position (meters): 0.020073599999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 1.16958744
#
# This iteration computes the area of the  108 th rectangle
# The area under the curve is the change in position (meters): 0.020300159999999998
# The cummulative area under the curve is the overall change in position until this point (meters): 1.1898875999999998
#
# This iteration computes the area of the  109 th rectangle
# The area under the curve is the change in position (meters): 0.020530399999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 1.2104179999999998
#
# This iteration computes the area of the  110 th rectangle
# The area under the curve is the change in position (meters): 0.0207644
# The cummulative area under the curve is the overall change in position until this point (meters): 1.2311823999999998
#
# This iteration computes the area of the  111 th rectangle
# The area under the curve is the change in position (meters): 0.02100224
# The cummulative area under the curve is the overall change in position until this point (meters): 1.2521846399999998
#
# This iteration computes the area of the  112 th rectangle
# The area under the curve is the change in position (meters): 0.021244000000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 1.27342864
#
# This iteration computes the area of the  113 th rectangle
# The area under the curve is the change in position (meters): 0.021489760000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 1.2949183999999998
#
# This iteration computes the area of the  114 th rectangle
# The area under the curve is the change in position (meters): 0.0217396
# The cummulative area under the curve is the overall change in position until this point (meters): 1.3166579999999999
#
# This iteration computes the area of the  115 th rectangle
# The area under the curve is the change in position (meters): 0.0219936
# The cummulative area under the curve is the overall change in position until this point (meters): 1.3386516
#
# This iteration computes the area of the  116 th rectangle
# The area under the curve is the change in position (meters): 0.022251840000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 1.36090344
#
# This iteration computes the area of the  117 th rectangle
# The area under the curve is the change in position (meters): 0.0225144
# The cummulative area under the curve is the overall change in position until this point (meters): 1.38341784
#
# This iteration computes the area of the  118 th rectangle
# The area under the curve is the change in position (meters): 0.02278136
# The cummulative area under the curve is the overall change in position until this point (meters): 1.4061991999999999
#
# This iteration computes the area of the  119 th rectangle
# The area under the curve is the change in position (meters): 0.0230528
# The cummulative area under the curve is the overall change in position until this point (meters): 1.429252
#
# This iteration computes the area of the  120 th rectangle
# The area under the curve is the change in position (meters): 0.0233288
# The cummulative area under the curve is the overall change in position until this point (meters): 1.4525808
#
# This iteration computes the area of the  121 th rectangle
# The area under the curve is the change in position (meters): 0.02360944
# The cummulative area under the curve is the overall change in position until this point (meters): 1.47619024
#
# This iteration computes the area of the  122 th rectangle
# The area under the curve is the change in position (meters): 0.023894799999999997
# The cummulative area under the curve is the overall change in position until this point (meters): 1.50008504
#
# This iteration computes the area of the  123 th rectangle
# The area under the curve is the change in position (meters): 0.02418496
# The cummulative area under the curve is the overall change in position until this point (meters): 1.52427
#
# This iteration computes the area of the  124 th rectangle
# The area under the curve is the change in position (meters): 0.024480000000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 1.54875
#
# This iteration computes the area of the  125 th rectangle
# The area under the curve is the change in position (meters): 0.024780000000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 1.57353
#
# This iteration computes the area of the  126 th rectangle
# The area under the curve is the change in position (meters): 0.025085040000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 1.59861504
#
# This iteration computes the area of the  127 th rectangle
# The area under the curve is the change in position (meters): 0.025395200000000007
# The cummulative area under the curve is the overall change in position until this point (meters): 1.62401024
#
# This iteration computes the area of the  128 th rectangle
# The area under the curve is the change in position (meters): 0.025710560000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 1.6497208
#
# This iteration computes the area of the  129 th rectangle
# The area under the curve is the change in position (meters): 0.026031200000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 1.6757520000000001
#
# This iteration computes the area of the  130 th rectangle
# The area under the curve is the change in position (meters): 0.026357200000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 1.7021092000000002
#
# This iteration computes the area of the  131 th rectangle
# The area under the curve is the change in position (meters): 0.026688640000000007
# The cummulative area under the curve is the overall change in position until this point (meters): 1.7287978400000001
#
# This iteration computes the area of the  132 th rectangle
# The area under the curve is the change in position (meters): 0.027025600000000007
# The cummulative area under the curve is the overall change in position until this point (meters): 1.7558234400000001
#
# This iteration computes the area of the  133 th rectangle
# The area under the curve is the change in position (meters): 0.027368160000000006
# The cummulative area under the curve is the overall change in position until this point (meters): 1.7831916
#
# This iteration computes the area of the  134 th rectangle
# The area under the curve is the change in position (meters): 0.027716400000000006
# The cummulative area under the curve is the overall change in position until this point (meters): 1.8109080000000002
#
# This iteration computes the area of the  135 th rectangle
# The area under the curve is the change in position (meters): 0.028070400000000006
# The cummulative area under the curve is the overall change in position until this point (meters): 1.8389784000000002
#
# This iteration computes the area of the  136 th rectangle
# The area under the curve is the change in position (meters): 0.028430240000000006
# The cummulative area under the curve is the overall change in position until this point (meters): 1.8674086400000003
#
# This iteration computes the area of the  137 th rectangle
# The area under the curve is the change in position (meters): 0.02879600000000001
# The cummulative area under the curve is the overall change in position until this point (meters): 1.8962046400000003
#
# This iteration computes the area of the  138 th rectangle
# The area under the curve is the change in position (meters): 0.02916776000000001
# The cummulative area under the curve is the overall change in position until this point (meters): 1.9253724000000003
#
# This iteration computes the area of the  139 th rectangle
# The area under the curve is the change in position (meters): 0.029545600000000012
# The cummulative area under the curve is the overall change in position until this point (meters): 1.9549180000000004
#
# This iteration computes the area of the  140 th rectangle
# The area under the curve is the change in position (meters): 0.029929600000000015
# The cummulative area under the curve is the overall change in position until this point (meters): 1.9848476000000004
#
# This iteration computes the area of the  141 th rectangle
# The area under the curve is the change in position (meters): 0.030319840000000015
# The cummulative area under the curve is the overall change in position until this point (meters): 2.0151674400000004
#
# This iteration computes the area of the  142 th rectangle
# The area under the curve is the change in position (meters): 0.030716400000000012
# The cummulative area under the curve is the overall change in position until this point (meters): 2.0458838400000006
#
# This iteration computes the area of the  143 th rectangle
# The area under the curve is the change in position (meters): 0.031119360000000016
# The cummulative area under the curve is the overall change in position until this point (meters): 2.0770032000000005
#
# This iteration computes the area of the  144 th rectangle
# The area under the curve is the change in position (meters): 0.03152880000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.1085320000000003
#
# This iteration computes the area of the  145 th rectangle
# The area under the curve is the change in position (meters): 0.031944800000000016
# The cummulative area under the curve is the overall change in position until this point (meters): 2.1404768000000005
#
# This iteration computes the area of the  146 th rectangle
# The area under the curve is the change in position (meters): 0.03236744000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.1728442400000003
#
# This iteration computes the area of the  147 th rectangle
# The area under the curve is the change in position (meters): 0.032796800000000015
# The cummulative area under the curve is the overall change in position until this point (meters): 2.20564104
#
# This iteration computes the area of the  148 th rectangle
# The area under the curve is the change in position (meters): 0.03323296000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.238874
#
# This iteration computes the area of the  149 th rectangle
# The area under the curve is the change in position (meters): 0.03367600000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.27255
#
# This iteration computes the area of the  150 th rectangle
# The area under the curve is the change in position (meters): 0.03412600000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.306676
#
# This iteration computes the area of the  151 th rectangle
# The area under the curve is the change in position (meters): 0.034583040000000016
# The cummulative area under the curve is the overall change in position until this point (meters): 2.34125904
#
# This iteration computes the area of the  152 th rectangle
# The area under the curve is the change in position (meters): 0.03504720000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.3763062400000003
#
# This iteration computes the area of the  153 th rectangle
# The area under the curve is the change in position (meters): 0.035518560000000025
# The cummulative area under the curve is the overall change in position until this point (meters): 2.4118248
#
# This iteration computes the area of the  154 th rectangle
# The area under the curve is the change in position (meters): 0.03599720000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.4478220000000004
#
# This iteration computes the area of the  155 th rectangle
# The area under the curve is the change in position (meters): 0.03648320000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.4843052000000005
#
# This iteration computes the area of the  156 th rectangle
# The area under the curve is the change in position (meters): 0.036976640000000026
# The cummulative area under the curve is the overall change in position until this point (meters): 2.5212818400000008
#
# This iteration computes the area of the  157 th rectangle
# The area under the curve is the change in position (meters): 0.03747760000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.5587594400000007
#
# This iteration computes the area of the  158 th rectangle
# The area under the curve is the change in position (meters): 0.037986160000000026
# The cummulative area under the curve is the overall change in position until this point (meters): 2.5967456000000007
#
# This iteration computes the area of the  159 th rectangle
# The area under the curve is the change in position (meters): 0.03850240000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.6352480000000007
#
# This iteration computes the area of the  160 th rectangle
# The area under the curve is the change in position (meters): 0.039026400000000024
# The cummulative area under the curve is the overall change in position until this point (meters): 2.6742744000000007
#
# This iteration computes the area of the  161 th rectangle
# The area under the curve is the change in position (meters): 0.03955824000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.7138326400000006
#
# This iteration computes the area of the  162 th rectangle
# The area under the curve is the change in position (meters): 0.04009800000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.7539306400000005
#
# This iteration computes the area of the  163 th rectangle
# The area under the curve is the change in position (meters): 0.040645760000000024
# The cummulative area under the curve is the overall change in position until this point (meters): 2.7945764000000004
#
# This iteration computes the area of the  164 th rectangle
# The area under the curve is the change in position (meters): 0.04120160000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 2.8357780000000004
#
# This iteration computes the area of the  165 th rectangle
# The area under the curve is the change in position (meters): 0.04176560000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 2.8775436000000005
#
# This iteration computes the area of the  166 th rectangle
# The area under the curve is the change in position (meters): 0.04233784000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 2.9198814400000006
#
# This iteration computes the area of the  167 th rectangle
# The area under the curve is the change in position (meters): 0.04291840000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 2.9627998400000006
#
# This iteration computes the area of the  168 th rectangle
# The area under the curve is the change in position (meters): 0.04350736000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 3.0063072000000006
#
# This iteration computes the area of the  169 th rectangle
# The area under the curve is the change in position (meters): 0.04410480000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.0504120000000006
#
# This iteration computes the area of the  170 th rectangle
# The area under the curve is the change in position (meters): 0.04471080000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 3.0951228000000004
#
# This iteration computes the area of the  171 th rectangle
# The area under the curve is the change in position (meters): 0.04532544000000002
# The cummulative area under the curve is the overall change in position until this point (meters): 3.1404482400000004
#
# This iteration computes the area of the  172 th rectangle
# The area under the curve is the change in position (meters): 0.045948800000000026
# The cummulative area under the curve is the overall change in position until this point (meters): 3.1863970400000006
#
# This iteration computes the area of the  173 th rectangle
# The area under the curve is the change in position (meters): 0.046580960000000025
# The cummulative area under the curve is the overall change in position until this point (meters): 3.2329780000000006
#
# This iteration computes the area of the  174 th rectangle
# The area under the curve is the change in position (meters): 0.04722200000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.2802000000000007
#
# This iteration computes the area of the  175 th rectangle
# The area under the curve is the change in position (meters): 0.04787200000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.3280720000000006
#
# This iteration computes the area of the  176 th rectangle
# The area under the curve is the change in position (meters): 0.048531040000000025
# The cummulative area under the curve is the overall change in position until this point (meters): 3.3766030400000004
#
# This iteration computes the area of the  177 th rectangle
# The area under the curve is the change in position (meters): 0.04919920000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.4258022400000003
#
# This iteration computes the area of the  178 th rectangle
# The area under the curve is the change in position (meters): 0.04987656000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.4756788000000003
#
# This iteration computes the area of the  179 th rectangle
# The area under the curve is the change in position (meters): 0.05056320000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.5262420000000003
#
# This iteration computes the area of the  180 th rectangle
# The area under the curve is the change in position (meters): 0.05125920000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.5775012000000004
#
# This iteration computes the area of the  181 th rectangle
# The area under the curve is the change in position (meters): 0.051964640000000034
# The cummulative area under the curve is the overall change in position until this point (meters): 3.6294658400000004
#
# This iteration computes the area of the  182 th rectangle
# The area under the curve is the change in position (meters): 0.052679600000000035
# The cummulative area under the curve is the overall change in position until this point (meters): 3.68214544
#
# This iteration computes the area of the  183 th rectangle
# The area under the curve is the change in position (meters): 0.053404160000000034
# The cummulative area under the curve is the overall change in position until this point (meters): 3.7355496
#
# This iteration computes the area of the  184 th rectangle
# The area under the curve is the change in position (meters): 0.05413840000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.789688
#
# This iteration computes the area of the  185 th rectangle
# The area under the curve is the change in position (meters): 0.05488240000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.8445704
#
# This iteration computes the area of the  186 th rectangle
# The area under the curve is the change in position (meters): 0.05563624000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 3.90020664
#
# This iteration computes the area of the  187 th rectangle
# The area under the curve is the change in position (meters): 0.05640000000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 3.95660664
#
# This iteration computes the area of the  188 th rectangle
# The area under the curve is the change in position (meters): 0.05717376000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 4.0137804
#
# This iteration computes the area of the  189 th rectangle
# The area under the curve is the change in position (meters): 0.05795760000000003
# The cummulative area under the curve is the overall change in position until this point (meters): 4.071738
#
# This iteration computes the area of the  190 th rectangle
# The area under the curve is the change in position (meters): 0.058751600000000036
# The cummulative area under the curve is the overall change in position until this point (meters): 4.1304896
#
# This iteration computes the area of the  191 th rectangle
# The area under the curve is the change in position (meters): 0.059555840000000033
# The cummulative area under the curve is the overall change in position until this point (meters): 4.19004544
#
# This iteration computes the area of the  192 th rectangle
# The area under the curve is the change in position (meters): 0.06037040000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.25041584
#
# This iteration computes the area of the  193 th rectangle
# The area under the curve is the change in position (meters): 0.06119536000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.3116112
#
# This iteration computes the area of the  194 th rectangle
# The area under the curve is the change in position (meters): 0.06203080000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.373641999999999
#
# This iteration computes the area of the  195 th rectangle
# The area under the curve is the change in position (meters): 0.06287680000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.436518799999999
#
# This iteration computes the area of the  196 th rectangle
# The area under the curve is the change in position (meters): 0.06373344000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.500252239999999
#
# This iteration computes the area of the  197 th rectangle
# The area under the curve is the change in position (meters): 0.06460080000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.564853039999999
#
# This iteration computes the area of the  198 th rectangle
# The area under the curve is the change in position (meters): 0.06547896000000004
# The cummulative area under the curve is the overall change in position until this point (meters): 4.630331999999999
#
# This iteration computes the area of the  199 th rectangle
# The area under the curve is the change in position (meters): 0.06636800000000005
# The cummulative area under the curve is the overall change in position until this point (meters): 4.696699999999999

# %%
# Adding the areas of all rectangles together
print("Final position is:", final_position, "meters")
# Out:
# Final position is: 4.696699999999999 meters

# %%
# This cell allows us to plot the Position as a function of time

position_vs_time = pd.Series(final_position_list, index=time_list) #Define a two(2) column array variable consisting of the variables "final_velocity_list" and "time"
position_vs_time.plot(xlabel = "Time (s)", ylabel = "position (m)", xlim=(0, 2), ylim=(0, velocity_vs_time.max() + 1), colormap='RdBu')
# Out:
# <Axes: xlabel='Time (s)', ylabel='position (m)'>

# %% [markdown]
# # Exercise 3.1
#
# 3.1.1. Look at the the code that generates the 'final velocity' and the 'final position.' What are their similarities and differences? What mathematical operation do they perform?
#
# .
#
#
# 3.1.2. The acceleration is not constant, so rigurously speaking you can't use the well-known 'kinematic equations.' Nevertheless, the velocity vs time plot consists essentially of 2 segments of constant acceleration (the slope of the velocity), and physics is about separating problems into constituent parts for which you can use simpler models. Below, in the first segment, the slope is:
#
# .
#
#  $ \frac{2.0 \rm{m/s}}{1.25 \rm{s}} = 1.6 \rm{m/s}^2$
#
# .
#
# and the $y$-intercept is $v_0 = 0$ m/s. Since,
#
# .
#
# $x = x_0 + v_0 \Delta t + \frac{1}{2}a (\Delta t)^2 $
#
# .
#
# for this particular case,
#
# .
#
# .
#
# $x =  \frac{1}{2} 1.6 \rm{m/s}^2 (1.25 \rm{s})^2 = 1.25 $ m
#
# .
#
# What is the slope and $y$-intercept of the second segment? Use the appropriate $\Delta t$ to calculate the distance traveled during the second segment and add it to the first segment. Do this with pen and paper.
#
# .
#
# 3.1.3. What is the total area under the curve? How does your pen and paper result compare to the numerical result output by the code cell above?

# %% [markdown]
# ![Unknown.png](data:image/png;base64,...)

# %%
## 3.1.1 What are the similarities and differences between the codes that generate the "final velocity" and the "final position"?
##
## Answer:

# %%
## 3.1.2 What is the slope and y-intercept of the second segment in the plot above?
##
## Answer:

# %%
## 3.1.3 What is the area under the curve of the simplified acceleration plot above and how does it compare to the numerical results?
##
## Answer:
